# %% [markdown]
# <a href="https://colab.research.google.com/github/ELISA1220/113-2Programming-language/blob/main/W2_4_1%E9%9A%A8%E5%A0%82%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
food_calories = {
    "grains": {
        "Rice": 200,
        "Noodles": 220,
        "Oatmeal": 150,
        "Sweet Potato": 90,
        "Corn": 100,
        "Whole Wheat Bread": 120
    },
    "proteins": {
        "Egg": 70,
        "Tofu": 80,
        "Chicken Breast": 165,
        "Fish": 140,
        "Shrimp": 90,
        "Pork": 210,
        "Beans": 130
    }
}

# %%
food_list = []

for category, foods in food_calories.items():
    for food in foods.keys():
        food_list.append({"Item": category.capitalize(), "Food": food})  # 增加食物名稱

# %%
import pandas as pd

df = pd.DataFrame(list(food_calories.keys()), columns=['Item'])

# %%
df
# Out:
#         Item               Food
# 0     Grains               Rice
# 1     Grains            Noodles
# 2     Grains            Oatmeal
# 3     Grains       Sweet Potato
# 4     Grains               Corn
# 5     Grains  Whole Wheat Bread
# 6   Proteins                Egg
# 7   Proteins               Tofu
# 8   Proteins     Chicken Breast
# 9   Proteins               Fish
# 10  Proteins             Shrimp
# 11  Proteins               Pork
# 12  Proteins              Beans

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
import pandas as pd
# read data and put it in a dataframe
# 在 google 工作表載入 gsheets
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1HFFz6ZHRSUNZVqqNJNl1kLd6gBn1rfFZh57qcx-Pdpo/edit?usp=sharing')

# %%
from gspread_dataframe import set_with_dataframe

# 選擇要更新的工作表（選擇第一個工作表）
worksheet = gsheets.get_worksheet(0)  # 如果是其他工作表，可以用 get_worksheet(index)

# 將 DataFrame 寫入 Google Sheets
set_with_dataframe(worksheet, df)

# %%
color_worksheet = gsheets.get_worksheet(1)

# %%
color_worksheet
# Out:
# <Worksheet '工作表2' id:2142836581>

# %%
df_color = pd.DataFrame(data)

# %%
df_color
# Out:
# 0          顏色名稱       代碼 顏色     分類
# 0        maroon  #800000         紅
# 1       darkred  #8B0000         紅
# 2         brown  #A52A2A         紅
# 3     firebrick  #B22222         紅
# 4       crimson  #DC143C         紅
# ..          ...      ... ..    ...
# 126   lightgray  #D3D3D3     黑~灰~白
# 127   gainsboro  #DCDCDC     黑~灰~白
# 128  whitesmoke  #F5F5F5     黑~灰~白
# 129  ghostwhite  #F8F8FF     黑~灰~白
# 130       white  #FFFFFF     黑~灰~白
#
# [131 rows x 4 columns]

# %%
# 取得 Google Sheets 內容
data = color_worksheet.get_all_values()  # 取得所有儲存格資料，回傳為 2D 陣列

# 將資料轉換為 DataFrame
df_color = pd.DataFrame(data)

# 設定第一行為標題（欄位名稱）
df_color.columns = df_color.iloc[0]  # 第一行設為欄位名稱
df_color = df_color[1:]  # 刪除第一行，保留數據部分

# 重設索引
df_color.reset_index(drop=True, inplace=True)

# %%
df_color
# Out:
# 0          顏色名稱       代碼 顏色     分類
# 0        maroon  #800000         紅
# 1       darkred  #8B0000         紅
# 2         brown  #A52A2A         紅
# 3     firebrick  #B22222         紅
# 4       crimson  #DC143C         紅
# ..          ...      ... ..    ...
# 126   lightgray  #D3D3D3     黑~灰~白
# 127   gainsboro  #DCDCDC     黑~灰~白
# 128  whitesmoke  #F5F5F5     黑~灰~白
# 129  ghostwhite  #F8F8FF     黑~灰~白
# 130       white  #FFFFFF     黑~灰~白
#
# [131 rows x 4 columns]

# %%
df_part = df_color[df_color['顏色名稱'] == 'ghostwhite']

# 選擇要更新的工作表（選擇第一個工作表）
color_worksheet = gsheets.get_worksheet(2)  # 如果是其他工作表，可以用 get_worksheet(index)

set_with_dataframe(color_worksheet, df_part)
